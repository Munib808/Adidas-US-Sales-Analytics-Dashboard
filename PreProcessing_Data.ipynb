# %%
import pandas as pd

# %%
df = pd.read_excel(r"E:\DS ML DL\Streamlit Practice\Project\Adidas US Sales Datasets.xlsx")
df.head()
# Out:
#    Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0         NaN          NaN  Adidas Sales Database                  NaN
# 1         NaN          NaN                    NaN                  NaN
# 2         NaN          NaN                    NaN                  NaN
# 3         NaN     Retailer            Retailer ID         Invoice Date
# 4         NaN  Foot Locker                1185732  2020-01-01 00:00:00
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6             Unnamed: 7      Unnamed: 8  \
# 0        NaN        NaN        NaN                    NaN             NaN
# 1        NaN        NaN        NaN                    NaN             NaN
# 2        NaN        NaN        NaN                    NaN             NaN
# 3     Region      State       City                Product  Price per Unit
# 4  Northeast   New York   New York  Men's Street Footwear              50
#
#    Unnamed: 9  Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# ...

# %%
df = df.drop(columns = ["Unnamed: 0"])
df = df.dropna()
df.head()
# Out:
#     Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3     Retailer  Retailer ID         Invoice Date     Region      State
# 4  Foot Locker      1185732  2020-01-01 00:00:00  Northeast   New York
# 5  Foot Locker      1185732  2020-01-02 00:00:00  Northeast   New York
# 6  Foot Locker      1185732  2020-01-03 00:00:00  Northeast   New York
# 7  Foot Locker      1185732  2020-01-04 00:00:00  Northeast   New York
#
#   Unnamed: 6                 Unnamed: 7      Unnamed: 8  Unnamed: 9  \
# 3       City                    Product  Price per Unit  Units Sold
# 4   New York      Men's Street Footwear              50        1200
# 5   New York    Men's Athletic Footwear              50        1000
# 6   New York    Women's Street Footwear              40        1000
# 7   New York  Women's Athletic Footwear              45         850
#
#    Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# ...

# %%
df.columns = ["Retailer"	,"Retailer ID"	,"Invoice Date"	,"Region"	,"State"	,"City"	,"Product",	"Price per Unit"	,"Units Sold",	"Total Sales"	,"Operating Profit"	,"Operating Margin"	,"Sales Method"]
df = df[df["Retailer"] != "Retailer"]

# %%
df = df.reset_index(drop = True)

# %%
df["Operating Margin"] = df["Operating Margin"] * 100
df['Retailer ID'] = df['Retailer ID'].astype(int)
df['Invoice Date'] = pd.to_datetime(df['Invoice Date'])
df['Price per Unit'] = df['Price per Unit'].astype(int)
df['Units Sold'] = df['Units Sold'].astype(int)
df['Total Sales'] = df['Total Sales'].astype(int)
df['Operating Profit'] = df['Operating Profit'].astype(int)
df['Operating Margin'] = df['Operating Margin'].astype(int)

# %%
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear              50        1200       600000
# 1    Men's Athletic Footwear              50        1000       500000
# 2    Women's Street Footwear              40        1000       400000
# 3  Women's Athletic Footwear              45         850       382500
# 4              Men's Apparel              60         900       540000
#
#    Operating Profit  Operating Margin Sales Method
# 0            300000                50     In-store
# ...

# %%
df.dtypes
# Out:
# Retailer                    object
# Retailer ID                  int64
# Invoice Date        datetime64[ns]
# Region                      object
# State                       object
# City                        object
# Product                     object
# Price per Unit               int64
# Units Sold                   int64
# Total Sales                  int64
# Operating Profit             int64
# Operating Margin             int64
# Sales Method                object
# dtype: object

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# %%
df.sort_values("invoice_date", inplace=True)

# %%
df["year"] = df["invoice_date"].dt.year
df["month"] = df["invoice_date"].dt.month
df["month_name"] = df["invoice_date"].dt.month_name()

# %%
df = df[df["total_sales"] > 0]

# %%
df.head()
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732   2020-01-01  Northeast      New York
# 499   Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 8203  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3888  Foot Locker      1185732   2020-01-01  Northeast      New York
# 7776  Foot Locker      1185732   2020-01-01  Northeast      New York
#
#               city                product  price_per_unit  units_sold  \
# 0         New York  Men's Street Footwear              50        1200
# 499   Philadelphia        Women's Apparel              75         275
# 8203  Philadelphia        Women's Apparel              53          83
# 3888      New York  Men's Street Footwear              47         336
# 7776      New York  Men's Street Footwear              34         384
#
#       total_sales  operating_profit  operating_margin sales_method  year  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9644 entries, 0 to 1200
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          9644 non-null   object
#  1   retailer_id       9644 non-null   int64
#  2   invoice_date      9644 non-null   datetime64[ns]
#  3   region            9644 non-null   object
#  4   state             9644 non-null   object
#  5   city              9644 non-null   object
#  6   product           9644 non-null   object
#  7   price_per_unit    9644 non-null   int64
#  8   units_sold        9644 non-null   int64
#  9   total_sales       9644 non-null   int64
#  10  operating_profit  9644 non-null   int64
#  11  operating_margin  9644 non-null   int64
#  12  sales_method      9644 non-null   object
#  13  year              9644 non-null   int32
#  14  month             9644 non-null   int32
#  15  month_name        9644 non-null   object
# ...

# %%
df.head()
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732   2020-01-01  Northeast      New York
# 499   Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 8203  Foot Locker      1185732   2020-01-01  Northeast  Pennsylvania
# 3888  Foot Locker      1185732   2020-01-01  Northeast      New York
# 7776  Foot Locker      1185732   2020-01-01  Northeast      New York
#
#               city                product  price_per_unit  units_sold  \
# 0         New York  Men's Street Footwear              50        1200
# 499   Philadelphia        Women's Apparel              75         275
# 8203  Philadelphia        Women's Apparel              53          83
# 3888      New York  Men's Street Footwear              47         336
# 7776      New York  Men's Street Footwear              34         384
#
#       total_sales  operating_profit  operating_margin sales_method  year  \
# ...

# %%
df.shape
# Out:
# (9644, 16)

# %%
df["region"].value_counts()
# Out:
# region
# West         2448
# Northeast    2376
# Midwest      1868
# South        1728
# Southeast    1224
# Name: count, dtype: int64

# %%
df["retailer"].value_counts()
# Out:
# retailer
# Foot Locker      2633
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: count, dtype: int64

# %%
df["product"].value_counts()
# Out:
# product
# Men's Street Footwear        1610
# Men's Athletic Footwear      1610
# Women's Apparel              1608
# Women's Street Footwear      1608
# Men's Apparel                1606
# Women's Athletic Footwear    1602
# Name: count, dtype: int64

# %%
df["sales_method"].value_counts()
# Out:
# sales_method
# Online      4887
# Outlet      3017
# In-store    1740
# Name: count, dtype: int64

# %%
df["city"].value_counts()
# Out:
# city
# Portland          360
# Charleston        288
# New York          216
# Philadelphia      216
# New Orleans       216
# Las Vegas         216
# Houston           216
# San Francisco     216
# Atlanta           216
# Los Angeles       216
# Phoenix           216
# Salt Lake City    216
# Dallas            216
# Oklahoma City     216
# Providence        216
# Richmond          216
# Boston            216
# Albuquerque       216
# Orlando           216
# Hartford          216
# Knoxville         216
# Birmingham        216
# Boise             216
# Manchester        216
# Jackson           216
# Little Rock       216
# Burlington        216
# Sioux Falls       144
# Miami             144
# Minneapolis       144
# Denver            144
# Newark            144
# Fargo             144
# Seattle           144
# Billings          144
# Des Moines        144
# Wilmington        144
# Anchorage         144
# Detroit           144
# Indianapolis      144
# St. Louis         144
# ...

# %%
df.to_csv("adidas_cleaned.csv", index=False)
